# %% [markdown]
# ### Emily Smith - 44008071
#
# ### DATA422-23S2:  Data Wrangling
#
# #### **Group Project**:  Scraping UN Data
#
# *last updated: 27 October 2023*
#
# Adapted from my Assignment 2 project concerning Formula 1 driver statistics.  This was one of my key responsibilities on the group project and does not contain work from other team members.

# %% [markdown]
# # Add packages

# %%
import Pkg
using Pkg
Pkg.add("Queryverse")
Pkg.add("ExcelFiles")
Pkg.add("HTTP")
Pkg.add("Gumbo")
Pkg.add("DataFrames")
Pkg.add("Cascadia")
Pkg.add("CSV")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %% [markdown]
# ## Get one table from one country using full link & selector

# %%
using HTTP
using Gumbo
using Cascadia
using DataFrames

# This function takes the strings link and css_selector (not a Selector object!)
# the page is parsed, the css_selector grabs only one table, and then each row is itterated through
# Only the first column (Variable) and last column (Value) are retained.
# These two vectors become columns in one DataFrame 'df' which is returned.
# This returns one dataframe representing one table from one css_selector
function get_country_data(link, css_selector)
    # Send an HTTP GET request and parse the response
    response = HTTP.get(link)
    body = String(response.body)
    parsed_html = parsehtml(body)
    
    # Use the Cascadia selector to extract the desired table
    selected_table = eachmatch(Selector(css_selector), parsed_html.root)[1]
    
    # Initialize empty vectors to store "Variable" and "Value" columns
    variables = String[]
    values = String[]
    
    # Iterate through table rows and extract data from the first and last columns
    for row in eachmatch(Selector("tr"), selected_table)
        columns = eachmatch(Selector("td"), row)
        variable = strip(nodeText(first(columns)))  # Remove leading/trailing spaces
        value = strip(nodeText(last(columns)))      # Remove leading/trailing spaces
        
        # Skip the row if the variable is empty or contains only spaces
        if !isempty(variable)
            push!(variables, variable)
            push!(values, value)
        end
    end
    
    # Create a dataframe with the extracted "Variable" and "Value" columns
    df = DataFrame(Variable = variables, Value = values)
    
    return df
end
# Out:
# get_country_data (generic function with 1 method)

# %% [markdown]
# ### Example output from one table from one country using a full link & selector

# %%
example_link = "https://data.un.org/en/iso/br.html"
example_css_selector = ".pure-menu-list > details:nth-child(1) > table:nth-child(2)"

get_country_data(example_link, example_css_selector)
# Out:
# 10×2 DataFrame
#  Row │ Variable                       Value
#      │ String                         String
# ─────┼─────────────────────────────────────────────────────
#    1 │ Region                         South America
#    2 │ Population (000, 2021)         213 993a
#    3 │ Pop. density (per km2, 2021)   25.6a
#    4 │ Capital city                   Brasilia
#    5 │ Capital city pop. (000, 2021)  4 559.0c,b
#    6 │ UN membership date             24-Oct-45
#    7 │ Surface area (km2)             8 515 767b
#    8 │ Sex ratio (m per 100 f)        96.5a
#    9 │ National currency              Brazilian Real (BRL)
#   10 │ Exchange rate (per US$)        5.2d

# %% [markdown]
# # Get all three-or-four tables from one country & one local link

# %%
using Gumbo
using HTTP
using Cascadia
using DataFrames

# This function takes the strings country_name and local_link
# the local link is the local address on the website, which will be combined
# to make the full usuable url to create a full link for get_country_data
# The function calls get_country_data for each of the four tables on most 
# pages, however if any tables are missing, the try/catch statement handles 
# the error gracefully, as there are two known exceptions.
# the three-or-four tables are concatinated and returned as combined_df
function get_all_tables(country_name, local_link)
    # Combine the URL
    url = "https://data.un.org/$local_link"
    
    selectors = [
        ".pure-menu-list > details:nth-child(1) > table:nth-child(2)",
        ".pure-menu-list > details:nth-child(2) > table:nth-child(2)",
        ".pure-menu-list > details:nth-child(3) > table:nth-child(2)",
        ".pure-menu-list > details:nth-child(4) > table:nth-child(2)"
    ]
    
    result_dfs = DataFrame[]
    
    for selector in selectors
        try
            example_df = get_country_data(url, selector)
            push!(result_dfs, insertcols!(example_df, 1, :Country => country_name))
        catch
            # Handle the expected error (selector not found) and continue to the next selector
        end
    end
    
    combined_df = vcat(result_dfs...)
    
    return combined_df
end
# Out:
# get_all_tables (generic function with 2 methods)

# %% [markdown]
# ### Example with four tables

# %%
example_country_name = "Algeria"
example_link = "en/iso/dz.html"

result_df = get_all_tables(example_country_name, example_link)
println(result_df)
# Out:
# 56×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ Algeria  Region                             Northern Africa
#    2 │ Algeria  Population (000, 2021)             44 617a
#    3 │ Algeria  Pop. density (per km2, 2021)       18.7a
#    4 │ Algeria  Capital city                       Algiers
#    5 │ Algeria  Capital city pop. (000, 2021)      2 729.3c,b
#    6 │ Algeria  UN membership date                 08-Oct-62
#    7 │ Algeria  Surface area (km2)                 2 381 741b
#    8 │ Algeria  Sex ratio (m per 100 f)            102.1a
#    9 │ Algeria  National currency                  Algerian Dinar (DZD)
#   10 │ Algeria  Exchange rate (per US$)            132.1d
#   11 │ Algeria  GDP: Gross domestic product (mil…  171 158b
#   12 │ Algeria  GDP growth rate (annual %, const…  0.8b
#   13 │ Algeria  GDP per capita (current US$)       3 975.5b
#   14 │ Algeria  Economy: Agriculture (% of Gross…  12.9b
#   15 │ Algeria  Economy: Industry (% of Gross Va…  39b
#   16 │ Algeria  Economy: Services and other acti…  48.1b
#   17 │ Algeria  Employment in agriculturee (% of…  9.7d
#   18 │ Algeria  Employment in industrye (% of em…  30.7d
#   19 │ Algeria  Employment in servicese (% emplo…  59.6d
#   20 │ Algeria  Unemploymente (% of labour force)  11.5d
#   21 │ Algeria  Labour force participation ratee…  14.6 /       67.0d
#   22 │ Algeria  CPI: Consumer Price Indexf (2010…  155g,d
#   23 │ Algeria  Agricultural production index (2…  112b
#   24 │ Algeria  International trade: exports (mi…  28 986e,d
#   25 │ Algeria  International trade: imports (mi…  41 678e,d
#   26 │ Algeria  International trade: balance (mi…  - 12 692e,d
#   27 │ Algeria  Balance of payments, current acc…  - 17 148b
#   28 │ Algeria  Population growth rateh (average…  2d
#   29 │ Algeria  Urban population (% of total pop…  73.2b
#   30 │ Algeria  Urban population growth rateh (a…  ...
#   31 │ Algeria  Fertility rate, totalh (live bir…  3d
#   32 │ Algeria  Life expectancy at birthh (femal…  77.8 /       75.4d
#   33 │ Algeria  Population age distribution (0-1…  30.9 /       10.1a
#   34 │ Algeria  International migrant stocki (00…  250.4 /        0.6d
#   35 │ Algeria  Refugees and others of concern t…  99.2d
#   36 │ Algeria  Infant mortality rateh (per 1 00…  21.2d
#   37 │ Algeria  Health: Current expenditure (% o…  6.2k
#   38 │ Algeria  Health: Physicians (per 1 000 po…  1.7k
#   39 │ Algeria  Education: Government expenditur…  ...
#   40 │ Algeria  Education: Primary gross enrol. …  104.9 /      109.7b
#   41 │ Algeria  Education: Secondary gross enrol…  ... / ...
#   42 │ Algeria  Education: Upper secondary gross…  ... / ...
#   43 │ Algeria  Intentional homicide rate (per 1…  ...
#   44 │ Algeria  Seats held by women in national …  26o
#   45 │ Algeria  Individuals using the Internet (…  49k
#   46 │ Algeria  Research & Development expenditu…  0.5r,s
#   47 │ Algeria  Threatened species (number)        170
#   48 │ Algeria  Forested area (% of land area)     0.8k
#   49 │ Algeria  CO2 emission estimates (million …  137.3 /        3.3k
#   50 │ Algeria  Energy production, primary (Peta…  6 254e,k
#   51 │ Algeria  Energy supply per capita (Gigajo…  58k
#   52 │ Algeria  Tourist/visitor arrivals at nati…  2 371b
#   53 │ Algeria  Important sites for terrestrial …  36.5d
#   54 │ Algeria  Pop. using safely managed drinki…  73.7 /       68.7d
#   55 │ Algeria  Pop. using safely managed sanita…  15.9 /       22.6d
#   56 │ Algeria  Net Official Development Assist.…  0.1b

# %% [markdown]
# ### Example with three tables

# %%
example_country_name = "Vatican"
example_link = "en/iso/va.html"

result_df = get_all_tables(example_country_name, example_link)
println(result_df)
# Out:
# 15×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼───────────────────────────────────────────────────────────────
#    1 │ Vatican  Region                             Southern Europe
#    2 │ Vatican  Population (000, 2021)             1a,b
#    3 │ Vatican  Pop. density (per km2, 2021)       1 845.5a,b
#    4 │ Vatican  Capital city                       Vatican City
#    5 │ Vatican  Capital city pop. (000, 2021)      0.8e
#    6 │ Vatican  Surface area (km2)                 ~0c,d
#    7 │ Vatican  National currency                  Euro (EUR)
#    8 │ Vatican  Exchange rate (per US$)            0.8f
#    9 │ Vatican  Population growth ratea,g (avera…  0.1f
#   10 │ Vatican  Urban population (% of total pop…  100d
#   11 │ Vatican  Urban population growth rateg (a…  ...
#   12 │ Vatican  International migrant stocka,h (…  0.8 /      100.0f
#   13 │ Vatican  Intentional homicide rate (per 1…  ...
#   14 │ Vatican  Threatened species (number)        2
#   15 │ Vatican  Forested areah (% of land area)    0e

# %% [markdown]
# # Get the dataframe of all country names & local links

# %%
using Gumbo
using HTTP
using Cascadia
using DataFrames

# This function takes the Strings link and link_prefix
# to find all link elements on a scraped page, and then step through each 
# item to only investigate links contianing the link_prefix
# The links returned are strings containing only the local 'stub' of the url,
# this is combined with the associated country name and combined in a dataframe
# The dataframe 'df' of country names and local links is returned
function extract_country_and_links(link, link_prefix)
    # Send an HTTP GET request and parse the response
    response = HTTP.get(link)
    html = String(response.body)
    parsed_html = parsehtml(html)
    
    # Find all <a> elements on the page
    a_elements = eachmatch(Selector("a"), parsed_html.root)
    
    # Initialize empty arrays to store country names and links
    country_names = String[]
    country_links = String[]
    
    # Iterate through <a> elements and filter out the ones with desired links
    for a_element in a_elements
        # Extract the link from the <a> element
        country_link = getattr(a_element, "href")
        
        # Check if the link starts with the specified prefix
        if startswith(country_link, link_prefix)
            # Extract the country name from the <a> element text
            country_name = nodeText(a_element)
            
            # Append the country name and link to the respective arrays
            push!(country_names, country_name)
            push!(country_links, country_link)
        end
    end

    # Create a dataframe from the extracted data
    df = DataFrame(Country = country_names, Link = country_links)
    
    return df
end

# Link and link prefix
country_list_link = "https://data.un.org/"
link_prefix = "en/iso/"

# Call the function to extract country names and links
country_list_df = extract_country_and_links(country_list_link, link_prefix)

# Print the resulting dataframe
println(country_list_df)
# Out:
# 232×2 DataFrame
#  Row │ Country                            Link
#      │ String                             String
# ─────┼───────────────────────────────────────────────────
#    1 │ Afghanistan                        en/iso/af.html
#    2 │ Albania                            en/iso/al.html
#    3 │ Algeria                            en/iso/dz.html
#    4 │ American Samoa                     en/iso/as.html
#    5 │ Andorra                            en/iso/ad.html
#    6 │ Angola                             en/iso/ao.html
#    7 │ Anguilla                           en/iso/ai.html
#    8 │ Antigua and Barbuda                en/iso/ag.html
#    9 │ Argentina                          en/iso/ar.html
#   10 │ Armenia                            en/iso/am.html
#   11 │ Aruba                              en/iso/aw.html
#   12 │ Australia                          en/iso/au.html
#   13 │ Austria                            en/iso/at.html
#   14 │ Azerbaijan                         en/iso/az.html
#   15 │ Bahamas                            en/iso/bs.html
#   16 │ Bahrain                            en/iso/bh.html
#   17 │ Bangladesh                         en/iso/bd.html
#   18 │ Barbados                           en/iso/bb.html
#   19 │ Belarus                            en/iso/by.html
#   20 │ Belgium                            en/iso/be.html
#   21 │ Belize                             en/iso/bz.html
#   22 │ Benin                              en/iso/bj.html
#   23 │ Bermuda                            en/iso/bm.html
#   24 │ Bhutan                             en/iso/bt.html
#   25 │ Bolivia (Plurinational State of)   en/iso/bo.html
#   26 │ Bonaire, Sint Eustatius and Saba   en/iso/bq.html
#   27 │ Bosnia and Herzegovina             en/iso/ba.html
#   28 │ Botswana                           en/iso/bw.html
#   29 │ Brazil                             en/iso/br.html
#   30 │ British Virgin Islands             en/iso/vg.html
#   31 │ Brunei Darussalam                  en/iso/bn.html
#   32 │ Bulgaria                           en/iso/bg.html
#   33 │ Burkina Faso                       en/iso/bf.html
#   34 │ Burundi                            en/iso/bi.html
#   35 │ Cabo Verde                         en/iso/cv.html
#   36 │ Cambodia                           en/iso/kh.html
#   37 │ Cameroon                           en/iso/cm.html
#   38 │ Canada                             en/iso/ca.html
#   39 │ Cayman Islands                     en/iso/ky.html
#   40 │ Central African Republic           en/iso/cf.html
#   41 │ Chad                               en/iso/td.html
#   42 │ Channel Islands                    en/iso/jg.html
#   43 │ Chile                              en/iso/cl.html
#   44 │ China                              en/iso/cn.html
#   45 │ China, Hong Kong SAR               en/iso/hk.html
#   46 │ China, Macao SAR                   en/iso/mo.html
#   47 │ Colombia                           en/iso/co.html
#   48 │ Comoros                            en/iso/km.html
#   49 │ Congo                              en/iso/cg.html
#   50 │ Cook Islands                       en/iso/ck.html
#   51 │ Costa Rica                         en/iso/cr.html
#   52 │ Croatia                            en/iso/hr.html
#   53 │ Cuba                               en/iso/cu.html
#   54 │ Curaçao                            en/iso/cw.html
#   55 │ Cyprus                             en/iso/cy.html
#   56 │ Czechia                            en/iso/cz.html
#   57 │ Côte d’Ivoire                      en/iso/ci.html
#   58 │ Democratic People's Republic of …  en/iso/kp.html
#   59 │ Democratic Republic of the Congo   en/iso/cd.html
#   60 │ Denmark                            en/iso/dk.html
#   61 │ Djibouti                           en/iso/dj.html
#   62 │ Dominica                           en/iso/dm.html
#   63 │ Dominican Republic                 en/iso/do.html
#   64 │ Ecuador                            en/iso/ec.html
#   65 │ Egypt                              en/iso/eg.html
#   66 │ El Salvador                        en/iso/sv.html
#   67 │ Equatorial Guinea                  en/iso/gq.html
#   68 │ Eritrea                            en/iso/er.html
#   69 │ Estonia                            en/iso/ee.html
#   70 │ Eswatini                           en/iso/sz.html
#   71 │ Ethiopia                           en/iso/et.html
#   72 │ Falkland Islands (Malvinas)        en/iso/fk.html
#   73 │ Faroe Islands                      en/iso/fo.html
#   74 │ Fiji                               en/iso/fj.html
#   75 │ Finland                            en/iso/fi.html
#   76 │ France                             en/iso/fr.html
#   77 │ French Guiana                      en/iso/gf.html
#   78 │ French Polynesia                   en/iso/pf.html
#   79 │ Gabon                              en/iso/ga.html
#   80 │ Gambia                             en/iso/gm.html
#   81 │ Georgia                            en/iso/ge.html
#   82 │ Germany                            en/iso/de.html
#   83 │ Ghana                              en/iso/gh.html
#   84 │ Gibraltar                          en/iso/gi.html
#   85 │ Greece                             en/iso/gr.html
#   86 │ Greenland                          en/iso/gl.html
#   87 │ Grenada                            en/iso/gd.html
#   88 │ Guadeloupe                         en/iso/gp.html
#   89 │ Guam                               en/iso/gu.html
#   90 │ Guatemala                          en/iso/gt.html
#   91 │ Guinea                             en/iso/gn.html
#   92 │ Guinea-Bissau                      en/iso/gw.html
#   93 │ Guyana                             en/iso/gy.html
#   94 │ Haiti                              en/iso/ht.html
#   95 │ Holy See                           en/iso/va.html
#   96 │ Honduras                           en/iso/hn.html
#   97 │ Hungary                            en/iso/hu.html
#   98 │ Iceland                            en/iso/is.html
#   99 │ India                              en/iso/in.html
#  100 │ Indonesia                          en/iso/id.html
#  101 │ Iran (Islamic Republic of)         en/iso/ir.html
#  102 │ Iraq                               en/iso/iq.html
#  103 │ Ireland                            en/iso/ie.html
#  104 │ Isle of Man                        en/iso/im.html
#  105 │ Israel                             en/iso/il.html
#  106 │ Italy                              en/iso/it.html
#  107 │ Jamaica                            en/iso/jm.html
#  108 │ Japan                              en/iso/jp.html
#  109 │ Jordan                             en/iso/jo.html
#  110 │ Kazakhstan                         en/iso/kz.html
#  111 │ Kenya                              en/iso/ke.html
#  112 │ Kiribati                           en/iso/ki.html
#  113 │ Kuwait                             en/iso/kw.html
#  114 │ Kyrgyzstan                         en/iso/kg.html
#  115 │ Lao People's Democratic Republic   en/iso/la.html
#  116 │ Latvia                             en/iso/lv.html
#  117 │ Lebanon                            en/iso/lb.html
#  118 │ Lesotho                            en/iso/ls.html
#  119 │ Liberia                            en/iso/lr.html
#  120 │ Libya                              en/iso/ly.html
#  121 │ Liechtenstein                      en/iso/li.html
#  122 │ Lithuania                          en/iso/lt.html
#  123 │ Luxembourg                         en/iso/lu.html
#  124 │ Madagascar                         en/iso/mg.html
#  125 │ Malawi                             en/iso/mw.html
#  126 │ Malaysia                           en/iso/my.html
#  127 │ Maldives                           en/iso/mv.html
#  128 │ Mali                               en/iso/ml.html
#  129 │ Malta                              en/iso/mt.html
#  130 │ Marshall Islands                   en/iso/mh.html
#  131 │ Martinique                         en/iso/mq.html
#  132 │ Mauritania                         en/iso/mr.html
#  133 │ Mauritius                          en/iso/mu.html
#  134 │ Mayotte                            en/iso/yt.html
#  135 │ Mexico                             en/iso/mx.html
#  136 │ Micronesia (Federated States of)   en/iso/fm.html
#  137 │ Monaco                             en/iso/mc.html
#  138 │ Mongolia                           en/iso/mn.html
#  139 │ Montenegro                         en/iso/me.html
#  140 │ Montserrat                         en/iso/ms.html
#  141 │ Morocco                            en/iso/ma.html
#  142 │ Mozambique                         en/iso/mz.html
#  143 │ Myanmar                            en/iso/mm.html
#  144 │ Namibia                            en/iso/na.html
#  145 │ Nauru                              en/iso/nr.html
#  146 │ Nepal                              en/iso/np.html
#  147 │ Netherlands                        en/iso/nl.html
#  148 │ New Caledonia                      en/iso/nc.html
#  149 │ New Zealand                        en/iso/nz.html
#  150 │ Nicaragua                          en/iso/ni.html
#  151 │ Niger                              en/iso/ne.html
#  152 │ Nigeria                            en/iso/ng.html
#  153 │ Niue                               en/iso/nu.html
#  154 │ Northern Mariana Islands           en/iso/mp.html
#  155 │ Norway                             en/iso/no.html
#  156 │ Oman                               en/iso/om.html
#  157 │ Pakistan                           en/iso/pk.html
#  158 │ Palau                              en/iso/pw.html
#  159 │ Panama                             en/iso/pa.html
#  160 │ Papua New Guinea                   en/iso/pg.html
#  161 │ Paraguay                           en/iso/py.html
#  162 │ Peru                               en/iso/pe.html
#  163 │ Philippines                        en/iso/ph.html
#  164 │ Poland                             en/iso/pl.html
#  165 │ Portugal                           en/iso/pt.html
#  166 │ Puerto Rico                        en/iso/pr.html
#  167 │ Qatar                              en/iso/qa.html
#  168 │ Republic of Korea                  en/iso/kr.html
#  169 │ Republic of Moldova                en/iso/md.html
#  170 │ Romania                            en/iso/ro.html
#  171 │ Russian Federation                 en/iso/ru.html
#  172 │ Rwanda                             en/iso/rw.html
#  173 │ Réunion                            en/iso/re.html
#  174 │ Saint Helena                       en/iso/sh.html
#  175 │ Saint Kitts and Nevis              en/iso/kn.html
#  176 │ Saint Lucia                        en/iso/lc.html
#  177 │ Saint Pierre and Miquelon          en/iso/pm.html
#  178 │ Saint Vincent and the Grenadines   en/iso/vc.html
#  179 │ Samoa                              en/iso/ws.html
#  180 │ San Marino                         en/iso/sm.html
#  181 │ Sao Tome and Principe              en/iso/st.html
#  182 │ Saudi Arabia                       en/iso/sa.html
#  183 │ Senegal                            en/iso/sn.html
#  184 │ Serbia                             en/iso/rs.html
#  185 │ Seychelles                         en/iso/sc.html
#  186 │ Sierra Leone                       en/iso/sl.html
#  187 │ Singapore                          en/iso/sg.html
#  188 │ Sint Maarten (Dutch part)          en/iso/sx.html
#  189 │ Slovakia                           en/iso/sk.html
#  190 │ Slovenia                           en/iso/si.html
#  191 │ Solomon Islands                    en/iso/sb.html
#  192 │ Somalia                            en/iso/so.html
#  193 │ South Africa                       en/iso/za.html
#  194 │ South Sudan                        en/iso/ss.html
#  195 │ Spain                              en/iso/es.html
#  196 │ Sri Lanka                          en/iso/lk.html
#  197 │ State of Palestine                 en/iso/ps.html
#  198 │ Sudan                              en/iso/sd.html
#  199 │ Suriname                           en/iso/sr.html
#  200 │ Sweden                             en/iso/se.html
#  201 │ Switzerland                        en/iso/ch.html
#  202 │ Syrian Arab Republic               en/iso/sy.html
#  203 │ Tajikistan                         en/iso/tj.html
#  204 │ Thailand                           en/iso/th.html
#  205 │ The former Yugoslav Republic of …  en/iso/mk.html
#  206 │ Timor-Leste                        en/iso/tl.html
#  207 │ Togo                               en/iso/tg.html
#  208 │ Tokelau                            en/iso/tk.html
#  209 │ Tonga                              en/iso/to.html
#  210 │ Trinidad and Tobago                en/iso/tt.html
#  211 │ Tunisia                            en/iso/tn.html
#  212 │ Turkey                             en/iso/tr.html
#  213 │ Turkmenistan                       en/iso/tm.html
#  214 │ Turks and Caicos Islands           en/iso/tc.html
#  215 │ Tuvalu                             en/iso/tv.html
#  216 │ Uganda                             en/iso/ug.html
#  217 │ Ukraine                            en/iso/ua.html
#  218 │ United Arab Emirates               en/iso/ae.html
#  219 │ United Kingdom                     en/iso/gb.html
#  220 │ United Republic of Tanzania        en/iso/tz.html
#  221 │ United States Virgin Islands       en/iso/vi.html
#  222 │ United States of America           en/iso/us.html
#  223 │ Uruguay                            en/iso/uy.html
#  224 │ Uzbekistan                         en/iso/uz.html
#  225 │ Vanuatu                            en/iso/vu.html
#  226 │ Venezuela (Bolivarian Republic o…  en/iso/ve.html
#  227 │ Viet Nam                           en/iso/vn.html
#  228 │ Wallis and Futuna Islands          en/iso/wf.html
#  229 │ Western Sahara                     en/iso/eh.html
#  230 │ Yemen                              en/iso/ye.html
#  231 │ Zambia                             en/iso/zm.html
#  232 │ Zimbabwe                           en/iso/zw.html

# %% [markdown]
# # WARNING - NEXT CELL SCRAPES ALL COUNTRIES

# %% [markdown]
# ## Automate through all countries & local links

# %%
# This line itterates through all countries/links in country_list_df
# and creates all_dfs as a dataframe filled with each country's seperate dataframe
# NEARLY 300 COUNTRIES
all_dfs = map(row -> get_all_tables(row.Country, row.Link), eachrow(country_list_df))
# Out:
# 232-element Vector{DataFrame}:
#  52×3 DataFrame
#  Row │ Country      Variable                           Value
#      │ String       String                             String
# ─────┼────────────────────────────────────────────────────────────────────
#    1 │ Afghanistan  Region                             Southern Asia
#    2 │ Afghanistan  Population (000, 2021)             39 835a
#    3 │ Afghanistan  Pop. density (per km2, 2021)       61a
#    4 │ Afghanistan  Capital city                       Kabul
#    5 │ Afghanistan  Capital city pop. (000, 2021)      4 114.0b
#    6 │ Afghanistan  UN membership date                 19-Nov-46
#    7 │ Afghanistan  Surface area (km2)                 652 864b
#    8 │ Afghanistan  Sex ratio (m per 100 f)            105.3a
#    9 │ Afghanistan  National currency                  Afghani (AFN)
#   10 │ Afghanistan  Exchange rate (per US$)            77.1c
#   11 │ Afghanistan  GDP: Gross domestic product (mil…  17 877b
#   ⋮  │      ⋮                       ⋮                          ⋮
#   43 │ Afghanistan  Intentional homicide rate (per 1…  6.7l
#   44 │ Afghanistan  Seats held by women in national …  27o
#   45 │ Afghanistan  Individuals using the Interneth …  11.4n
#   46 │ Afghanistan  Threatened species (number)        48
#   47 │ Afghanistan  Forested areah (% of land area)    1.9l
#   48 │ Afghanistan  Energy production, primary (Peta…  89l
#   49 │ Afghanistan  Energy supply per capita (Gigajo…  4l
#   50 │ Afghanistan  Important sites for terrestrial …  5.7c
#   51 │ Afghanistan  Pop. using safely managed drinki…  36.4 /       24.5c
#   52 │ Afghanistan  Net Official Development Assist.…  21.34b
#                                                            31 rows omitted
#  55×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼────────────────────────────────────────────────────────────────
#    1 │ Albania  Region                             Southern Europe
#    2 │ Albania  Population (000, 2021)             2 873a
#    3 │ Albania  Pop. density (per km2, 2021)       104.9a
#    4 │ Albania  Capital city                       Tirana
#    5 │ Albania  Capital city pop. (000, 2021)      484.6b
#    6 │ Albania  UN membership date                 14-Dec-55
#    7 │ Albania  Surface area (km2)                 28 748b
#    8 │ Albania  Sex ratio (m per 100 f)            103.6a
#    9 │ Albania  National currency                  Lek (ALL)
#   10 │ Albania  Exchange rate (per US$)            100.8c
#   11 │ Albania  GDP: Gross domestic product (mil…  15 278b
#   ⋮  │    ⋮                     ⋮                          ⋮
#   46 │ Albania  Research & Development expenditu…  ...
#   47 │ Albania  Threatened species (number)        147
#   48 │ Albania  Forested areah (% of land area)    28.8m
#   49 │ Albania  CO2 emission estimates (million …  4.3 /        1.5m
#   50 │ Albania  Energy production, primary (Peta…  81m
#   51 │ Albania  Energy supply per capita (Gigajo…  32m
#   52 │ Albania  Tourist/visitor arrivals at nati…  6 128b
#   53 │ Albania  Important sites for terrestrial …  50.5c
#   54 │ Albania  Pop. using safely managed sanita…  44.1 /       53.6c
#   55 │ Albania  Net Official Development Assist.…  0.18b
#                                                        34 rows omitted
#  56×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ Algeria  Region                             Northern Africa
#    2 │ Algeria  Population (000, 2021)             44 617a
#    3 │ Algeria  Pop. density (per km2, 2021)       18.7a
#    4 │ Algeria  Capital city                       Algiers
#    5 │ Algeria  Capital city pop. (000, 2021)      2 729.3c,b
#    6 │ Algeria  UN membership date                 08-Oct-62
#    7 │ Algeria  Surface area (km2)                 2 381 741b
#    8 │ Algeria  Sex ratio (m per 100 f)            102.1a
#    9 │ Algeria  National currency                  Algerian Dinar (DZD)
#   10 │ Algeria  Exchange rate (per US$)            132.1d
#   11 │ Algeria  GDP: Gross domestic product (mil…  171 158b
#   ⋮  │    ⋮                     ⋮                           ⋮
#   47 │ Algeria  Threatened species (number)        170
#   48 │ Algeria  Forested area (% of land area)     0.8k
#   49 │ Algeria  CO2 emission estimates (million …  137.3 /        3.3k
#   50 │ Algeria  Energy production, primary (Peta…  6 254e,k
#   51 │ Algeria  Energy supply per capita (Gigajo…  58k
#   52 │ Algeria  Tourist/visitor arrivals at nati…  2 371b
#   53 │ Algeria  Important sites for terrestrial …  36.5d
#   54 │ Algeria  Pop. using safely managed drinki…  73.7 /       68.7d
#   55 │ Algeria  Pop. using safely managed sanita…  15.9 /       22.6d
#   56 │ Algeria  Net Official Development Assist.…  0.1b
#                                                          35 rows omitted
#  22×3 DataFrame
#  Row │ Country         Variable                           Value
#      │ String          String                             String
# ─────┼───────────────────────────────────────────────────────────────────────
#    1 │ American Samoa  Region                             Polynesia
#    2 │ American Samoa  Population (000, 2021)             55a
#    3 │ American Samoa  Pop. density (per km2, 2021)       275.5a
#    4 │ American Samoa  Capital city                       Pago Pago
#    5 │ American Samoa  Capital city pop. (000, 2021)      48.5c
#    6 │ American Samoa  Surface area (km2)                 199b
#    7 │ American Samoa  National currency                  US Dollar (USD)
#    8 │ American Samoa  Employment in agriculture (% of …  ...
#    9 │ American Samoa  Employment in industry (% of emp…  ...
#   10 │ American Samoa  Employment in services (% employ…  ...
#   11 │ American Samoa  Unemployment (% of labour force)   ...
#   12 │ American Samoa  Population growth rateg (average…  -0.2h
#   13 │ American Samoa  Urban population (% of total pop…  87.1b
#   14 │ American Samoa  Urban population growth rateg (a…  ...
#   15 │ American Samoa  International migrant stock (000…  23.6 /       42.8h
#   16 │ American Samoa  Education: Government expenditur…  ...
#   17 │ American Samoa  Intentional homicide rate (per 1…  5.4j
#   18 │ American Samoa  Research & Development expenditu…  ...
#   19 │ American Samoa  Threatened species (number)        102
#   20 │ American Samoa  Forested area (% of land area)     86c
#   21 │ American Samoa  Tourist/visitor arrivals at nati…  20c
#   22 │ American Samoa  Important sites for terrestrial …  25h
#  37×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │ Andorra  Region                             Southern Europe
#    2 │ Andorra  Population (000, 2021)             77a
#    3 │ Andorra  Pop. density (per km2, 2021)       164.6a
#    4 │ Andorra  Capital city                       Andorra la Vella
#    5 │ Andorra  Capital city pop. (000, 2021)      22.6c
#    6 │ Andorra  UN membership date                 28-Jul-93
#    7 │ Andorra  Surface area (km2)                 468b
#    8 │ Andorra  National currency                  Euro (EUR)
#    9 │ Andorra  Exchange rate (per US$)            0.8d
#   10 │ Andorra  GDP: Gross domestic product (mil…  3 154b
#   11 │ Andorra  GDP growth rate (annual %, const…  1.8b
#   ⋮  │    ⋮                     ⋮                           ⋮
#   28 │ Andorra  Intentional homicide rate (per 1…  ...
#   29 │ Andorra  Seats held by women in national …  46.4n
#   30 │ Andorra  Individuals using the Internet (…  91.6o
#   31 │ Andorra  Threatened species (number)        14
#   32 │ Andorra  Forested area (% of land area)     34c
#   33 │ Andorra  Energy production, primaryj (Pet…  1c
#   34 │ Andorra  Energy supply per capita (Gigajo…  122c
#   35 │ Andorra  Tourist/visitor arrivals at nati…  3 042c
#   36 │ Andorra  Important sites for terrestrial …  26.1d
#   37 │ Andorra  Pop. using safely managed sanita…  100.0 /      100.0d
#                                                         16 rows omitted
#  54×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼────────────────────────────────────────────────────────────────
#    1 │ Angola   Region                             Middle Africa
#    2 │ Angola   Population (000, 2021)             33 934a
#    3 │ Angola   Pop. density (per km2, 2021)       27.2a
#    4 │ Angola   Capital city                       Luanda
#    5 │ Angola   Capital city pop. (000, 2021)      8 044.7c,b
#    6 │ Angola   UN membership date                 01-Dec-76
#    7 │ Angola   Surface area (km2)                 1 246 700b
#    8 │ Angola   Sex ratio (m per 100 f)            97.9a
#    9 │ Angola   National currency                  Kwanza (AOA)
#   10 │ Angola   Exchange rate (per US$)            656.2d
#   11 │ Angola   GDP: Gross domestic product (mil…  85 001b
#   ⋮  │    ⋮                     ⋮                          ⋮
#   45 │ Angola   Individuals using the Internete …  14.3l
#   46 │ Angola   Research & Development expenditu…  ~0.0q,r,s,n
#   47 │ Angola   Threatened species (number)        193
#   48 │ Angola   Forested area (% of land area)     54.3j
#   49 │ Angola   CO2 emission estimates (million …  18.8 /        0.6j
#   50 │ Angola   Energy production, primary (Peta…  3 793j
#   51 │ Angola   Energy supply per capita (Gigajo…  17j
#   52 │ Angola   Tourist/visitor arrivals at nati…  218b
#   53 │ Angola   Important sites for terrestrial …  28.1d
#   54 │ Angola   Net Official Development Assist.…  0.03b
#                                                        33 rows omitted
#  36×3 DataFrame
#  Row │ Country   Variable                           Value                      ⋯
#      │ String    String                             String                     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Anguilla  Region                             Caribbean                  ⋯
#    2 │ Anguilla  Population (000, 2021)             15a
#    3 │ Anguilla  Pop. density (per km2, 2021)       168.1a
#    4 │ Anguilla  Capital city                       The Valley
#    5 │ Anguilla  Capital city pop. (000, 2021)      1.4d                       ⋯
#    6 │ Anguilla  Surface area (km2)                 91b
#    7 │ Anguilla  National currency                  E. Caribbean Dollar (XCD)c
#    8 │ Anguilla  Exchange rate (per US$)            2.7e
#    9 │ Anguilla  GDP: Gross domestic product (mil…  380b                       ⋯
#   10 │ Anguilla  GDP growth rate (annual %, const…  5.4b
#   11 │ Anguilla  GDP per capita (current US$)       25 528.6b
#   ⋮  │    ⋮                      ⋮                              ⋮              ⋱
#   27 │ Anguilla  Education: Secondary gross enrol…  99.2 /      102.4b
#   28 │ Anguilla  Education: Upper secondary gross…  94.9 /       99.5b         ⋯
#   29 │ Anguilla  Intentional homicide rate (per 1…  ...
#   30 │ Anguilla  Individuals using the Internetg …  81.6m
#   31 │ Anguilla  Threatened species (number)        69
#   32 │ Anguilla  Forested areag (% of land area)    61.1d                      ⋯
#   33 │ Anguilla  Energy production, primaryg (Pet…  0d
#   34 │ Anguilla  Energy supply per capitag (Gigaj…  141d
#   35 │ Anguilla  Tourist/visitor arrivals at nati…  95b
#   36 │ Anguilla  Important sites for terrestrial …  6.8e                       ⋯
#                                                                 15 rows omitted
#  50×3 DataFrame
#  Row │ Country              Variable                           Value           ⋯
#      │ String               String                             String          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Antigua and Barbuda  Region                             Caribbean       ⋯
#    2 │ Antigua and Barbuda  Population (000, 2021)             99a
#    3 │ Antigua and Barbuda  Pop. density (per km2, 2021)       224.4a
#    4 │ Antigua and Barbuda  Capital city                       Saint John's
#    5 │ Antigua and Barbuda  Capital city pop. (000, 2021)      20.8d           ⋯
#    6 │ Antigua and Barbuda  UN membership date                 11-Nov-81
#    7 │ Antigua and Barbuda  Surface area (km2)                 442b
#    8 │ Antigua and Barbuda  Sex ratio (m per 100 f)            93.4a
#    9 │ Antigua and Barbuda  National currency                  E. Caribbean Do ⋯
#   10 │ Antigua and Barbuda  Exchange rate (per US$)            2.7e
#   11 │ Antigua and Barbuda  GDP: Gross domestic product (mil…  1 662b
#   ⋮  │          ⋮                           ⋮                              ⋮   ⋱
#   41 │ Antigua and Barbuda  Intentional homicide rate (per 1…  ...
#   42 │ Antigua and Barbuda  Seats held by women in national …  11.1n           ⋯
#   43 │ Antigua and Barbuda  Individuals using the Interneth …  73o
#   44 │ Antigua and Barbuda  Threatened species (number)        73
#   45 │ Antigua and Barbuda  Forested areah (% of land area)    18.8d
#   46 │ Antigua and Barbuda  Energy production, primaryh (Pet…  0d              ⋯
#   47 │ Antigua and Barbuda  Energy supply per capitah (Gigaj…  75d
#   48 │ Antigua and Barbuda  Tourist/visitor arrivals at nati…  269d
#   49 │ Antigua and Barbuda  Important sites for terrestrial …  26.9e
#   50 │ Antigua and Barbuda  Net Official Development Assist.…  1.69b           ⋯
#                                                     1 column and 29 rows omitted
#  55×3 DataFrame
#  Row │ Country    Variable                           Value
#      │ String     String                             String
# ─────┼────────────────────────────────────────────────────────────────────
#    1 │ Argentina  Region                             South America
#    2 │ Argentina  Population (000, 2021)             45 606a
#    3 │ Argentina  Pop. density (per km2, 2021)       16.7a
#    4 │ Argentina  Capital city                       Buenos Aires
#    5 │ Argentina  Capital city pop. (000, 2021)      15 057.3d,c
#    6 │ Argentina  UN membership date                 24-Oct-45
#    7 │ Argentina  Surface area (km2)                 2 796 427b,c
#    8 │ Argentina  Sex ratio (m per 100 f)            95.3a
#    9 │ Argentina  National currency                  Argentine Peso (ARS)
#   10 │ Argentina  Exchange rate (per US$)            84e
#   11 │ Argentina  GDP: Gross domestic product (mil…  449 664c
#   ⋮  │     ⋮                      ⋮                           ⋮
#   46 │ Argentina  Research & Development expenditu…  0.5k
#   47 │ Argentina  Threatened species (number)        320
#   48 │ Argentina  Forested areaf (% of land area)    10.5k
#   49 │ Argentina  CO2 emission estimates (million …  171.2 /        3.8k
#   50 │ Argentina  Energy production, primary (Peta…  3 152k
#   51 │ Argentina  Energy supply per capita (Gigajo…  74k
#   52 │ Argentina  Tourist/visitor arrivals at nati…  6 942k
#   53 │ Argentina  Important sites for terrestrial …  32.1e
#   54 │ Argentina  Pop. using safely managed sanita…  47.1 / ...e
#   55 │ Argentina  Net Official Development Assist.…  0c
#                                                            34 rows omitted
#  55×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │ Armenia  Region                             Western Asia
#    2 │ Armenia  Population (000, 2021)             2 968a
#    3 │ Armenia  Pop. density (per km2, 2021)       104.3a
#    4 │ Armenia  Capital city                       Yerevan
#    5 │ Armenia  Capital city pop. (000, 2021)      1 083.3b
#    6 │ Armenia  UN membership date                 02-Mar-92
#    7 │ Armenia  Surface area (km2)                 29 743b
#    8 │ Armenia  Sex ratio (m per 100 f)            88.8a
#    9 │ Armenia  National currency                  Armenian Dram (AMD)
#   10 │ Armenia  Exchange rate (per US$)            522.6c
#   11 │ Armenia  GDP: Gross domestic product (mil…  13 673b
#   ⋮  │    ⋮                     ⋮                           ⋮
#   46 │ Armenia  Research & Development expenditu…  0.2q,r,m
#   47 │ Armenia  Threatened species (number)        116
#   48 │ Armenia  Forested area (% of land area)     11.6h,m
#   49 │ Armenia  CO2 emission estimates (million …  5.4 /        1.8m
#   50 │ Armenia  Energy production, primary (Peta…  37m
#   51 │ Armenia  Energy supply per capita (Gigajo…  44m
#   52 │ Armenia  Tourist/visitor arrivals at nati…  1 652m
#   53 │ Armenia  Important sites for terrestrial …  22.6c
#   54 │ Armenia  Pop. using safely managed sanita…  71.4 / ...c
#   55 │ Armenia  Net Official Development Assist.…  3b
#                                                         34 rows omitted
#  46×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │ Aruba    Region                             Caribbean
#    2 │ Aruba    Population (000, 2021)             107a
#    3 │ Aruba    Pop. density (per km2, 2021)       595.5a
#    4 │ Aruba    Capital city                       Oranjestad
#    5 │ Aruba    Capital city pop. (000, 2021)      29.9c
#    6 │ Aruba    Surface area (km2)                 180b
#    7 │ Aruba    Sex ratio (m per 100 f)            90.2a
#    8 │ Aruba    National currency                  Aruban Florin (AWG)
#    9 │ Aruba    Exchange rate (per US$)            1.8d
#   10 │ Aruba    GDP: Gross domestic product (mil…  3 293b
#   11 │ Aruba    GDP growth rate (annual %, const…  -0.7b
#   ⋮  │    ⋮                     ⋮                           ⋮
#   37 │ Aruba    Education: Secondary gross enrol…  ... / ...
#   38 │ Aruba    Education: Upper secondary gross…  ... / ...
#   39 │ Aruba    Intentional homicide rate (per 1…  ...
#   40 │ Aruba    Individuals using the Internetv …  97.2w
#   41 │ Aruba    Threatened species (number)        60
#   42 │ Aruba    Forested areav (% of land area)    2.3c
#   43 │ Aruba    Energy production, primaryv (Pet…  1c
#   44 │ Aruba    Energy supply per capitav (Gigaj…  118c
#   45 │ Aruba    Tourist/visitor arrivals at nati…  1 119b
#   46 │ Aruba    Important sites for terrestrial …  37.1d
#                                                         25 rows omitted
#  55×3 DataFrame
#  Row │ Country    Variable                           Value
#      │ String     String                             String
# ─────┼───────────────────────────────────────────────────────────────────────
#    1 │ Australia  Region                             Oceania
#    2 │ Australia  Population (000, 2021)             25 788a,b
#    3 │ Australia  Pop. density (per km2, 2021)       3.4a,b
#    4 │ Australia  Capital city                       Canberra
#    5 │ Australia  Capital city pop. (000, 2021)      452.5e,d
#    6 │ Australia  UN membership date                 01-Nov-45
#    7 │ Australia  Surface area (km2)                 7 692 024c,d
#    8 │ Australia  Sex ratio (m per 100 f)            99.2a,b
#    9 │ Australia  National currency                  Australian Dollar (AUD)
#   10 │ Australia  Exchange rate (per US$)            1.3f
#   11 │ Australia  GDP: Gross domestic product (mil…  1 380 208d
#   ⋮  │     ⋮                      ⋮                             ⋮
#   46 │ Australia  Research & Development expenditu…  1.9t
#   47 │ Australia  Threatened speciesx (number)       1 773
#   48 │ Australia  Forested area (% of land area)     17.4s
#   49 │ Australia  CO2 emission estimatesx (million…  388.7 /       15.3d
#   50 │ Australia  Energy production, primaryx (Pet…  17 231s
#   51 │ Australia  Energy supply per capitax (Gigaj…  217s
#   52 │ Australia  Tourist/visitor arrivals at nati…  9 246s
#   53 │ Australia  Important sites for terrestrial …  56.6f
#   54 │ Australia  Pop. using safely managed drinki…  99.0 / ...f
#   55 │ Australia  Net Official Development Assist.…  0.23t
#                                                               34 rows omitted
#  55×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │ Austria  Region                             Western Europe
#    2 │ Austria  Population (000, 2021)             9 043a
#    3 │ Austria  Pop. density (per km2, 2021)       109.7a
#    4 │ Austria  Capital city                       Vienna
#    5 │ Austria  Capital city pop. (000, 2021)      1 915.3b
#    6 │ Austria  UN membership date                 14-Dec-55
#    7 │ Austria  Surface area (km2)                 83 878b
#    8 │ Austria  Sex ratio (m per 100 f)            97.4a
#    9 │ Austria  National currency                  Euro (EUR)
#   10 │ Austria  Exchange rate (per US$)            0.8c
#   11 │ Austria  GDP: Gross domestic product (mil…  445 075b
#   ⋮  │    ⋮                     ⋮                           ⋮
#   46 │ Austria  Research & Development expenditu…  3.2h,b
#   47 │ Austria  Threatened species (number)        188
#   48 │ Austria  Forested area (% of land area)     47.2l
#   49 │ Austria  CO2 emission estimates (million …  62.8 /        7.1b
#   50 │ Austria  Energy production, primary (Peta…  488l
#   51 │ Austria  Energy supply per capita (Gigajo…  155l
#   52 │ Austria  Tourist/visitor arrivals at nati…  31 884b
#   53 │ Austria  Important sites for terrestrial …  67.4c
#   54 │ Austria  Pop. using safely managed sanita…  100.0 /       99.2c
#   55 │ Austria  Net Official Development Assist.…  0.3m
#                                                         34 rows omitted
#  ⋮
#  30×3 DataFrame
#  Row │ Country                       Variable                           Value  ⋯
#      │ String                        String                             String ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ United States Virgin Islands  Region                             Caribb ⋯
#    2 │ United States Virgin Islands  Population (000, 2021)             104a
#    3 │ United States Virgin Islands  Pop. density (per km2, 2021)       297.8a
#    4 │ United States Virgin Islands  Capital city                       Charlo
#    5 │ United States Virgin Islands  Capital city pop. (000, 2021)      52.3c  ⋯
#    6 │ United States Virgin Islands  Surface area (km2)                 347b
#    7 │ United States Virgin Islands  Sex ratio (m per 100 f)            90.4a
#    8 │ United States Virgin Islands  National currency                  US Dol
#    9 │ United States Virgin Islands  Employment in agricultured (% of…  3.2e   ⋯
#   10 │ United States Virgin Islands  Employment in industryd (% of em…  19.6e
#   11 │ United States Virgin Islands  Employment in servicesd (% emplo…  77.2e
#   ⋮  │              ⋮                                ⋮                         ⋱
#   21 │ United States Virgin Islands  Infant mortality ratef (per 1 00…  8.2e
#   22 │ United States Virgin Islands  Intentional homicide rate (per 1…  ...    ⋯
#   23 │ United States Virgin Islands  Individuals using the Internetd …  64.4h
#   24 │ United States Virgin Islands  Research & Development expenditu…  ...
#   25 │ United States Virgin Islands  Threatened species (number)        87
#   26 │ United States Virgin Islands  Forested area (% of land area)     56c    ⋯
#   27 │ United States Virgin Islands  Energy production, primaryd (Pet…  0c
#   28 │ United States Virgin Islands  Energy supply per capitad (Gigaj…  1c
#   29 │ United States Virgin Islands  Tourist/visitor arrivals at nati…  381c
#   30 │ United States Virgin Islands  Important sites for terrestrial …  33.9e  ⋯
#                                                      1 column and 9 rows omitted
#  55×3 DataFrame
#  Row │ Country                   Variable                           Value      ⋯
#      │ String                    String                             String     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ United States of America  Region                             Northern A ⋯
#    2 │ United States of America  Population (000, 2021)             332 915a
#    3 │ United States of America  Pop. density (per km2, 2021)       36.4a
#    4 │ United States of America  Capital city                       Washington
#    5 │ United States of America  Capital city pop. (000, 2021)      5 264.5b   ⋯
#    6 │ United States of America  UN membership date                 24-Oct-45
#    7 │ United States of America  Surface area (km2)                 9 833 517b
#    8 │ United States of America  Sex ratio (m per 100 f)            97.9a
#    9 │ United States of America  National currency                  US Dollar  ⋯
#   10 │ United States of America  GDP: Gross domestic product (mil…  21 433 226
#   11 │ United States of America  GDP growth rate (annual %, const…  2.2b
#   ⋮  │            ⋮                              ⋮                             ⋱
#   46 │ United States of America  Threatened species (number)        1 841
#   47 │ United States of America  Forested area (% of land area)     33.9h,n    ⋯
#   48 │ United States of America  CO2 emission estimatest (million…  4 766.4 /
#   49 │ United States of America  Energy production, primaryu (Pet…  90 881n
#   50 │ United States of America  Energy supply per capitau (Gigaj…  286n
#   51 │ United States of America  Tourist/visitor arrivals at nati…  79 256b    ⋯
#   52 │ United States of America  Important sites for terrestrial …  34.9i
#   53 │ United States of America  Pop. using safely managed drinki…  97.5 / ...
#   54 │ United States of America  Pop. using safely managed sanita…  97.3 / ...
#   55 │ United States of America  Net Official Development Assist.…  0.18x      ⋯
#                                                     1 column and 34 rows omitted
#  55×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │ Uruguay  Region                             South America
#    2 │ Uruguay  Population (000, 2021)             3 485a
#    3 │ Uruguay  Pop. density (per km2, 2021)       19.9a
#    4 │ Uruguay  Capital city                       Montevideo
#    5 │ Uruguay  Capital city pop. (000, 2021)      1 744.7c,b
#    6 │ Uruguay  UN membership date                 18-Dec-45
#    7 │ Uruguay  Surface area (km2)                 173 626b
#    8 │ Uruguay  Sex ratio (m per 100 f)            93.6a
#    9 │ Uruguay  National currency                  Peso Uruguayo (UYU)
#   10 │ Uruguay  Exchange rate (per US$)            42.3d
#   11 │ Uruguay  GDP: Gross domestic product (mil…  56 046b
#   ⋮  │    ⋮                     ⋮                           ⋮
#   46 │ Uruguay  Research & Development expenditu…  0.4j
#   47 │ Uruguay  Threatened species (number)        136
#   48 │ Uruguay  Forested area (% of land area)     11.4j
#   49 │ Uruguay  CO2 emission estimates (million …  6.2 /        1.8j
#   50 │ Uruguay  Energy production, primary (Peta…  137j
#   51 │ Uruguay  Energy supply per capita (Gigajo…  65j
#   52 │ Uruguay  Tourist/visitor arrivals at nati…  3 469j
#   53 │ Uruguay  Important sites for terrestrial …  23.3d
#   54 │ Uruguay  Pop. using safely managed drinki…  94.6 / ...d
#   55 │ Uruguay  Net Official Development Assist.…  0.07l
#                                                         34 rows omitted
#  55×3 DataFrame
#  Row │ Country     Variable                           Value
#      │ String      String                             String
# ─────┼─────────────────────────────────────────────────────────────────────
#    1 │ Uzbekistan  Region                             Central Asia
#    2 │ Uzbekistan  Population (000, 2021)             33 936a
#    3 │ Uzbekistan  Pop. density (per km2, 2021)       79.8a
#    4 │ Uzbekistan  Capital city                       Tashkent
#    5 │ Uzbekistan  Capital city pop. (000, 2021)      2 490.3b
#    6 │ Uzbekistan  UN membership date                 02-Mar-92
#    7 │ Uzbekistan  Surface area (km2)                 448 969b
#    8 │ Uzbekistan  Sex ratio (m per 100 f)            99.6a
#    9 │ Uzbekistan  National currency                  Uzbekistan Sum (UZS)
#   10 │ Uzbekistan  Exchange rate (per US$)            10 483.0c,d
#   11 │ Uzbekistan  GDP: Gross domestic product (mil…  57 921b
#   ⋮  │     ⋮                       ⋮                           ⋮
#   46 │ Uzbekistan  Research & Development expenditu…  0.1p
#   47 │ Uzbekistan  Threatened species (number)        62
#   48 │ Uzbekistan  Forested area (% of land area)     8.3p
#   49 │ Uzbekistan  CO2 emission estimates (million …  108.0 /        3.3p
#   50 │ Uzbekistan  Energy production, primary (Peta…  2 310p
#   51 │ Uzbekistan  Energy supply per capita (Gigajo…  60p
#   52 │ Uzbekistan  Tourist/visitor arrivals at nati…  5 346p
#   53 │ Uzbekistan  Important sites for terrestrial …  17.7d
#   54 │ Uzbekistan  Pop. using safely managed drinki…  86.1 /       31.1d
#   55 │ Uzbekistan  Net Official Development Assist.…  1.96b
#                                                             34 rows omitted
#  52×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼─────────────────────────────────────────────────────────
#    1 │ Vanuatu  Region                             Melanesia
#    2 │ Vanuatu  Population (000, 2021)             314a
#    3 │ Vanuatu  Pop. density (per km2, 2021)       25.8a
#    4 │ Vanuatu  Capital city                       Port Vila
#    5 │ Vanuatu  Capital city pop. (000, 2021)      52.7c
#    6 │ Vanuatu  UN membership date                 15-Sep-81
#    7 │ Vanuatu  Surface area (km2)                 12 189b
#    8 │ Vanuatu  Sex ratio (m per 100 f)            102.7a
#    9 │ Vanuatu  National currency                  Vatu (VUV)
#   10 │ Vanuatu  Exchange rate (per US$)            107.7d
#   11 │ Vanuatu  GDP: Gross domestic product (mil…  907b
#   ⋮  │    ⋮                     ⋮                       ⋮
#   43 │ Vanuatu  Seats held by women in national …  0u
#   44 │ Vanuatu  Individuals using the Internet (…  25.7i,t
#   45 │ Vanuatu  Threatened species (number)        150
#   46 │ Vanuatu  Forested areai (% of land area)    36.3c
#   47 │ Vanuatu  Energy production, primary (Peta…  1i,c
#   48 │ Vanuatu  Energy supply per capita (Gigajo…  12c
#   49 │ Vanuatu  Tourist/visitor arrivals at nati…  121b
#   50 │ Vanuatu  Important sites for terrestrial …  2.9d
#   51 │ Vanuatu  Pop. using safely managed drinki…  56.6 / ...d
#   52 │ Vanuatu  Net Official Development Assist.…  14.1b
#                                                 31 rows omitted
#  54×3 DataFrame
#  Row │ Country                            Variable                           V ⋯
#      │ String                             String                             S ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Venezuela (Bolivarian Republic o…  Region                             S ⋯
#    2 │ Venezuela (Bolivarian Republic o…  Population (000, 2021)             2
#    3 │ Venezuela (Bolivarian Republic o…  Pop. density (per km2, 2021)       3
#    4 │ Venezuela (Bolivarian Republic o…  Capital city                       C
#    5 │ Venezuela (Bolivarian Republic o…  Capital city pop. (000, 2021)      2 ⋯
#    6 │ Venezuela (Bolivarian Republic o…  UN membership date                 1
#    7 │ Venezuela (Bolivarian Republic o…  Surface area (km2)                 9
#    8 │ Venezuela (Bolivarian Republic o…  Sex ratio (m per 100 f)            9
#    9 │ Venezuela (Bolivarian Republic o…  National currency                  B ⋯
#   10 │ Venezuela (Bolivarian Republic o…  Exchange rate (per US$)            1
#   11 │ Venezuela (Bolivarian Republic o…  GDP: Gross domestic product (mil…  1
#   ⋮  │                 ⋮                                  ⋮                    ⋱
#   45 │ Venezuela (Bolivarian Republic o…  Individuals using the Internete …  6
#   46 │ Venezuela (Bolivarian Republic o…  Research & Development expenditu…  . ⋯
#   47 │ Venezuela (Bolivarian Republic o…  Threatened species (number)        7
#   48 │ Venezuela (Bolivarian Republic o…  Forested areae (% of land area)    5
#   49 │ Venezuela (Bolivarian Republic o…  CO2 emission estimates (million …  1
#   50 │ Venezuela (Bolivarian Republic o…  Energy production, primary (Peta…  4 ⋯
#   51 │ Venezuela (Bolivarian Republic o…  Energy supply per capita (Gigajo…  5
#   52 │ Venezuela (Bolivarian Republic o…  Tourist/visitor arrivals at nati…  4
#   53 │ Venezuela (Bolivarian Republic o…  Important sites for terrestrial …  5
#   54 │ Venezuela (Bolivarian Republic o…  Net Official Development Assist.…  . ⋯
#                                                     1 column and 33 rows omitted
#  52×3 DataFrame
#  Row │ Country   Variable                           Value
#      │ String    String                             String
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ Viet Nam  Region                             South-eastern Asia
#    2 │ Viet Nam  Population (000, 2021)             98 169a
#    3 │ Viet Nam  Pop. density (per km2, 2021)       316.6a
#    4 │ Viet Nam  Capital city                       Hanoi
#    5 │ Viet Nam  Capital city pop. (000, 2021)      4 479.6c,b
#    6 │ Viet Nam  UN membership date                 20-Sep-77
#    7 │ Viet Nam  Surface area (km2)                 331 236b
#    8 │ Viet Nam  Sex ratio (m per 100 f)            99.7a
#    9 │ Viet Nam  National currency                  Dong (VND)
#   10 │ Viet Nam  Exchange rate (per US$)            23 131.0d
#   11 │ Viet Nam  GDP: Gross domestic product (mil…  261 921b
#   ⋮  │    ⋮                      ⋮                           ⋮
#   43 │ Viet Nam  Individuals using the Internet (…  68.7b
#   44 │ Viet Nam  Research & Development expenditu…  0.5r
#   45 │ Viet Nam  Threatened species (number)        803
#   46 │ Viet Nam  Forested areag (% of land area)    46.7l
#   47 │ Viet Nam  CO2 emission estimates (million …  226.5 /        2.4l
#   48 │ Viet Nam  Energy production, primary (Peta…  2 553l
#   49 │ Viet Nam  Energy supply per capita (Gigajo…  31l
#   50 │ Viet Nam  Tourist/visitor arrivals at nati…  18 009b
#   51 │ Viet Nam  Important sites for terrestrial …  40d
#   52 │ Viet Nam  Net Official Development Assist.…  0.45b
#                                                          31 rows omitted
#  22×3 DataFrame
#  Row │ Country                    Variable                           Value     ⋯
#      │ String                     String                             String    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Wallis and Futuna Islands  Region                             Polynesia ⋯
#    2 │ Wallis and Futuna Islands  Population (000, 2021)             11a
#    3 │ Wallis and Futuna Islands  Pop. density (per km2, 2021)       79.2a
#    4 │ Wallis and Futuna Islands  Capital city                       Matu-Utu
#    5 │ Wallis and Futuna Islands  Capital city pop. (000, 2021)      1d        ⋯
#    6 │ Wallis and Futuna Islands  Surface area (km2)                 142b
#    7 │ Wallis and Futuna Islands  National currency                  CFP Franc
#    8 │ Wallis and Futuna Islands  Exchange rate (per US$)            97.2e
#    9 │ Wallis and Futuna Islands  International trade: exportsf (m…  2e        ⋯
#   10 │ Wallis and Futuna Islands  International trade: importsf (m…  69e
#   11 │ Wallis and Futuna Islands  International trade: balancef (m…  -68e
#   12 │ Wallis and Futuna Islands  Population growth rateh (average…  -1.7e
#   13 │ Wallis and Futuna Islands  Urban population (% of total pop…  0b        ⋯
#   14 │ Wallis and Futuna Islands  Urban population growth rateh (a…  ...
#   15 │ Wallis and Futuna Islands  International migrant stocki (00…  2.0 /
#   16 │ Wallis and Futuna Islands  Individuals using the Internet (…  ...
#   17 │ Wallis and Futuna Islands  Threatened species (number)        94        ⋯
#   18 │ Wallis and Futuna Islands  Forested areaf (% of land area)    41.6d
#   19 │ Wallis and Futuna Islands  Energy production, primaryf (Pet…  0d
#   20 │ Wallis and Futuna Islands  Energy supply per capita (Gigajo…  31d
#   21 │ Wallis and Futuna Islands  Important sites for terrestrial …  0e        ⋯
#   22 │ Wallis and Futuna Islands  Pop. using safely managed drinki…  ... /
#                                                                 1 column omitted
#  24×3 DataFrame
#  Row │ Country         Variable                           Value                ⋯
#      │ String          String                             String               ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Western Sahara  Region                             Northern Africa      ⋯
#    2 │ Western Sahara  Population (000, 2021)             612a
#    3 │ Western Sahara  Pop. density (per km2, 2021)       2.3a
#    4 │ Western Sahara  Capital city                       El Aaiún
#    5 │ Western Sahara  Capital city pop. (000, 2021)      232.4d               ⋯
#    6 │ Western Sahara  Surface area (km2)                 266 000b,c
#    7 │ Western Sahara  Sex ratio (m per 100 f)            109.4a
#    8 │ Western Sahara  National currency                  Moroccan Dirham (MAD
#    9 │ Western Sahara  Exchange rate (per US$)            8.9e                 ⋯
#   10 │ Western Sahara  Employment in agriculturef (% of…  19.8e
#   11 │ Western Sahara  Employment in industryf (% of em…  25.7e
#   ⋮  │       ⋮                         ⋮                            ⋮          ⋱
#   15 │ Western Sahara  Population growth rateg (average…  2.5e
#   16 │ Western Sahara  Urban population (% of total pop…  86.8c                ⋯
#   17 │ Western Sahara  Urban population growth rateg (a…  ...
#   18 │ Western Sahara  Fertility rate, totalg (live bir…  2.4e
#   19 │ Western Sahara  Life expectancy at birthg (femal…  71.9 /       68.2e
#   20 │ Western Sahara  Population age distribution (0-1…  26.9 /        6.6a   ⋯
#   21 │ Western Sahara  International migrant stockf (00…  5.4 /        0.9e
#   22 │ Western Sahara  Infant mortality rateg (per 1 00…  28.8e
#   23 │ Western Sahara  Threatened species (number)        70
#   24 │ Western Sahara  Forested areaf (% of land area)    2.5d                 ⋯
#                                                      1 column and 3 rows omitted
#  54×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼────────────────────────────────────────────────────────────────
#    1 │ Yemen    Region                             Western Asia
#    2 │ Yemen    Population (000, 2021)             30 491a
#    3 │ Yemen    Pop. density (per km2, 2021)       57.8a
#    4 │ Yemen    Capital city                       Sana'a
#    5 │ Yemen    Capital city pop. (000, 2021)      2 874.4c,b
#    6 │ Yemen    UN membership date                 30-Sep-47
#    7 │ Yemen    Surface area (km2)                 527 968b
#    8 │ Yemen    Sex ratio (m per 100 f)            101.5a
#    9 │ Yemen    National currency                  Yemeni Rial (YER)
#   10 │ Yemen    Exchange rate (per US$)            250.2d
#   11 │ Yemen    GDP: Gross domestic product (mil…  24 935b
#   ⋮  │    ⋮                     ⋮                          ⋮
#   45 │ Yemen    Individuals using the Internet (…  26.7e,q
#   46 │ Yemen    Threatened species (number)        329
#   47 │ Yemen    Forested areae (% of land area)    1r
#   48 │ Yemen    CO2 emission estimates (million …  8.0 /        0.3r
#   49 │ Yemen    Energy production, primary (Peta…  74r
#   50 │ Yemen    Energy supply per capita (Gigajo…  5r
#   51 │ Yemen    Tourist/visitor arrivals at nati…  ...
#   52 │ Yemen    Important sites for terrestrial …  27.9d
#   53 │ Yemen    Pop. using safely managed sanita…  60.6 / ...d
#   54 │ Yemen    Net Official Development Assist.…  28.95r
#                                                        33 rows omitted
#  54×3 DataFrame
#  Row │ Country  Variable                           Value
#      │ String   String                             String
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ Zambia   Region                             Eastern Africa
#    2 │ Zambia   Population (000, 2021)             18 921a
#    3 │ Zambia   Pop. density (per km2, 2021)       25.5a
#    4 │ Zambia   Capital city                       Lusaka
#    5 │ Zambia   Capital city pop. (000, 2021)      2 646.6b
#    6 │ Zambia   UN membership date                 01-Dec-64
#    7 │ Zambia   Surface area (km2)                 752 612b
#    8 │ Zambia   Sex ratio (m per 100 f)            98.1a
#    9 │ Zambia   National currency                  Zambian Kwacha (ZMW)
#   10 │ Zambia   Exchange rate (per US$)            21.2c
#   11 │ Zambia   GDP: Gross domestic product (mil…  23 085b
#   ⋮  │    ⋮                     ⋮                           ⋮
#   45 │ Zambia   Threatened species (number)        121
#   46 │ Zambia   Forested areah (% of land area)    60.8n
#   47 │ Zambia   CO2 emission estimates (million …  6.7 /        0.4n
#   48 │ Zambia   Energy production, primary (Peta…  469n
#   49 │ Zambia   Energy supply per capita (Gigajo…  30n
#   50 │ Zambia   Tourist/visitor arrivals at nati…  1 072n
#   51 │ Zambia   Important sites for terrestrial …  46.1c
#   52 │ Zambia   Pop. using safely managed drinki…  50.5 / ...c
#   53 │ Zambia   Pop. using safely managed sanita…  ... /       23.8c
#   54 │ Zambia   Net Official Development Assist.…  4.16b
#                                                          33 rows omitted
#  55×3 DataFrame
#  Row │ Country   Variable                           Value
#      │ String    String                             String
# ─────┼────────────────────────────────────────────────────────────────────
#    1 │ Zimbabwe  Region                             Eastern Africa
#    2 │ Zimbabwe  Population (000, 2021)             15 092a
#    3 │ Zimbabwe  Pop. density (per km2, 2021)       39a
#    4 │ Zimbabwe  Capital city                       Harare
#    5 │ Zimbabwe  Capital city pop. (000, 2021)      1 521.3b
#    6 │ Zimbabwe  UN membership date                 25-Aug-80
#    7 │ Zimbabwe  Surface area (km2)                 390 757b
#    8 │ Zimbabwe  Sex ratio (m per 100 f)            91.4a
#    9 │ Zimbabwe  National currency                  Zimbabwe Dollar (ZWL)
#   10 │ Zimbabwe  Exchange rate (per US$)            81.8c
#   11 │ Zimbabwe  GDP: Gross domestic product (mil…  21 441b
#   ⋮  │    ⋮                      ⋮                            ⋮
#   46 │ Zimbabwe  Threatened species (number)        124
#   47 │ Zimbabwe  Forested aread (% of land area)    45.3e
#   48 │ Zimbabwe  CO2 emission estimates (million …  11.7 /        0.8e
#   49 │ Zimbabwe  Energy production, primary (Peta…  448e
#   50 │ Zimbabwe  Energy supply per capita (Gigajo…  34e
#   51 │ Zimbabwe  Tourist/visitor arrivals at nati…  2 580e
#   52 │ Zimbabwe  Important sites for terrestrial …  81.2c
#   53 │ Zimbabwe  Pop. using safely managed drinki…  64.6 /       12.9c
#   54 │ Zimbabwe  Pop. using safely managed sanita…  16.0 /       30.2c
#   55 │ Zimbabwe  Net Official Development Assist.…  4.25b
#                                                            34 rows omitted

# %% [markdown]
# ### Combine the above dataframe-of-dataframes into one dataframe

# %%
# This combines all_dfs into one 11475×3 dataframe
final_country_data = vcat(all_dfs...)
# Out:
# 11475×3 DataFrame
#    Row │ Country      Variable                           Value
#        │ String       String                             String
# ───────┼────────────────────────────────────────────────────────────────────
#      1 │ Afghanistan  Region                             Southern Asia
#      2 │ Afghanistan  Population (000, 2021)             39 835a
#      3 │ Afghanistan  Pop. density (per km2, 2021)       61a
#      4 │ Afghanistan  Capital city                       Kabul
#      5 │ Afghanistan  Capital city pop. (000, 2021)      4 114.0b
#      6 │ Afghanistan  UN membership date                 19-Nov-46
#      7 │ Afghanistan  Surface area (km2)                 652 864b
#      8 │ Afghanistan  Sex ratio (m per 100 f)            105.3a
#      9 │ Afghanistan  National currency                  Afghani (AFN)
#     10 │ Afghanistan  Exchange rate (per US$)            77.1c
#     11 │ Afghanistan  GDP: Gross domestic product (mil…  17 877b
#    ⋮   │      ⋮                       ⋮                          ⋮
#  11466 │ Zimbabwe     Threatened species (number)        124
#  11467 │ Zimbabwe     Forested aread (% of land area)    45.3e
#  11468 │ Zimbabwe     CO2 emission estimates (million …  11.7 /        0.8e
#  11469 │ Zimbabwe     Energy production, primary (Peta…  448e
#  11470 │ Zimbabwe     Energy supply per capita (Gigajo…  34e
#  11471 │ Zimbabwe     Tourist/visitor arrivals at nati…  2 580e
#  11472 │ Zimbabwe     Important sites for terrestrial …  81.2c
#  11473 │ Zimbabwe     Pop. using safely managed drinki…  64.6 /       12.9c
#  11474 │ Zimbabwe     Pop. using safely managed sanita…  16.0 /       30.2c
#  11475 │ Zimbabwe     Net Official Development Assist.…  4.25b
#                                                           11454 rows omitted

# %% [markdown]
# ### Export as CSV

# %%
using CSV

# export the final_country_data for use by other team members
CSV.write("final_country_data.csv", final_country_data, writeheader=true)
# Out:
# "final_country_data.csv"
